# %%
import matplotlib.pyplot as plt # use to draw graph
import numpy as np # use to store computed data
import pandas as pd # use to read file


x = np.array(["125-150","150-75","175-200","obve 200","under 125"])
data_type = pd.read_csv("fifa_data.csv")
y = np.array([data_type[(data_type['Weight']>='125lbs') & (data_type['Weight']<'150lbs')]['Weight'].count(),
             data_type[(data_type['Weight']>='150lbs') & (data_type['Weight']<'175lbs')]['Weight'].count(),
             data[(data_type['Weight']>='175lbs') & (data_type['Weight']<'200lbs')]['Weight'].count(),
             data_type[(data_type['Weight']<'125lbs') ]['Weight'].count(),
             data_type[(data_type['Weight']>'200lbs') ]['Weight'].count()])

plt.title("Weight of Professional Soccer PLayers (lbs)");
plt.pie(y,labels=x, autopct='%1.2f%%');
plt.show()

#Bar graph
def addlabels(x,y):
    index = 0;
    for i in x:
        plt.text(index,y[index],y[index])
        index +=1;
plt.bar(x,y)
addlabels(x,y)
plt.show()

#Box plot
plt.boxplot(y)
plt.show()
